# %% [markdown]
# Trains a 100-Layer DenseNet on the CIFAR10 dataset.<br>
# With data augmentation:<br>
# Greater than 93.55% test accuracy in 200 epochs<br>
# 225sec per epoch on GTX 1080Ti<br>
# Densely Connected Convolutional Networks<br>
# https://arxiv.org/pdf/1608.06993.pdf<br>
# http://openaccess.thecvf.com/content_cvpr_2017/papers/<br>
#     Huang_Densely_Connected_Convolutional_CVPR_2017_paper.pdf<br>
# Network below is similar to 100-Layer DenseNet-BC (k=12)<br>

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %%
from keras.layers import Dense, Conv2D, BatchNormalization
from keras.layers import MaxPooling2D, AveragePooling2D
from keras.layers import Input, Flatten, Dropout
from keras.layers import concatenate, Activation
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.callbacks import LearningRateScheduler
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.datasets import cifar10
from keras.utils import plot_model
from keras.utils import to_categorical
import os
import numpy as np
import math
# Out:
# /Users/jonasgacrama/miniconda/envs/tf/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# training parameters

# %%
batch_size = 32
epochs = 200
data_augmentation = True

# %% [markdown]
# network parameters

# %%
num_classes = 10
num_dense_blocks = 3
use_max_pool = False

# %% [markdown]
# DenseNet-BC with dataset augmentation<br>
# Growth rate   | Depth |  Accuracy (paper)| Accuracy (this)      |<br>
# 12            | 100   |  95.49%          | 93.74%               |<br>
# 24            | 250   |  96.38%          | requires big mem GPU |<br>
# 40            | 190   |  96.54%          | requires big mem GPU |

# %%
growth_rate = 12
depth = 100
num_bottleneck_layers = (depth - 4) // (2 * num_dense_blocks)

# %%
num_filters_bef_dense_block = 2 * growth_rate
compression_factor = 0.5

# %% [markdown]
# load the CIFAR10 data

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# input image dimensions

# %%
input_shape = x_train.shape[1:]

# %% [markdown]
# mormalize data

# %%
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %% [markdown]
# convert class vectors to binary class matrices.

# %%
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# start model definition<br>
# densenet CNNs (composite function) are made of BN-ReLU-Conv2D

# %%
inputs = Input(shape=input_shape)
x = BatchNormalization()(inputs)
x = Activation('relu')(x)
x = Conv2D(num_filters_bef_dense_block,
           kernel_size=3,
           padding='same',
           kernel_initializer='he_normal')(x)
x = concatenate([inputs, x])
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2022-11-13 20:38:07.372845: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-13 20:38:07.372943: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# stack of dense blocks bridged by transition layers

# %%
for i in range(num_dense_blocks):
    # a dense block is a stack of bottleneck layers
    for j in range(num_bottleneck_layers):
        y = BatchNormalization()(x)
        y = Activation('relu')(y)
        y = Conv2D(4 * growth_rate,
                   kernel_size=1,
                   padding='same',
                   kernel_initializer='he_normal')(y)
        if not data_augmentation:
            y = Dropout(0.2)(y)
        y = BatchNormalization()(y)
        y = Activation('relu')(y)
        y = Conv2D(growth_rate,
                   kernel_size=3,
                   padding='same',
                   kernel_initializer='he_normal')(y)
        if not data_augmentation:
            y = Dropout(0.2)(y)
        x = concatenate([x, y])

    # no transition layer after the last dense block
    if i == num_dense_blocks - 1:
        continue

    # transition layer compresses num of feature maps and reduces the size by 2
    num_filters_bef_dense_block += num_bottleneck_layers * growth_rate
    num_filters_bef_dense_block = int(num_filters_bef_dense_block * compression_factor)
    y = BatchNormalization()(x)
    y = Conv2D(num_filters_bef_dense_block,
               kernel_size=1,
               padding='same',
               kernel_initializer='he_normal')(y)
    if not data_augmentation:
        y = Dropout(0.2)(y)
    x = AveragePooling2D()(y)

# %% [markdown]
# add classifier on top<br>
# after average pooling, size of feature map is 1 x 1

# %%
x = AveragePooling2D(pool_size=8)(x)
y = Flatten()(x)
outputs = Dense(num_classes,
                kernel_initializer='he_normal',
                activation='softmax')(y)

# %% [markdown]
# instantiate and compile model<br>
# orig paper uses SGD but RMSprop works better for DenseNet

# %%
model = Model(inputs=inputs, outputs=outputs)
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(1e-3),
              metrics=['acc'])
model.summary()
# enable this if pydot can be installed
# pip install pydot
plot_model(model, to_file="cifar10-densenet.png", show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  batch_normalization (BatchNorm  (None, 32, 32, 3)   12          ['input_1[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 3)    0           ['batch_normalization[0][0]']
#
#  conv2d (Conv2D)                (None, 32, 32, 24)   672         ['activation[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 27)   0           ['input_1[0][0]',
#                                                                   'conv2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 27)  108         ['concatenate[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 27)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 48)   1344        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 48)  192         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 48)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 12)   5196        ['activation_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 39)   0           ['concatenate[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 39)  156         ['concatenate_1[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 39)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 48)   1920        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 48)  192         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 48)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 12)   5196        ['activation_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 51)   0           ['concatenate_1[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 51)  204         ['concatenate_2[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 51)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 48)   2496        ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 48)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 48)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 12)   5196        ['activation_6[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 63)   0           ['concatenate_2[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 63)  252         ['concatenate_3[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 63)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 48)   3072        ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 48)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 32, 32, 48)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 12)   5196        ['activation_8[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 75)   0           ['concatenate_3[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 75)  300         ['concatenate_4[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 75)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 48)   3648        ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 48)  192         ['conv2d_9[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 12)   5196        ['activation_10[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 87)   0           ['concatenate_4[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 87)  348         ['concatenate_5[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 87)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 48)   4224        ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 48)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 12)   5196        ['activation_12[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 32, 32, 99)   0           ['concatenate_5[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 99)  396         ['concatenate_6[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 99)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 48)   4800        ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 48)  192         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 12)   5196        ['activation_14[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 32, 32, 111)  0           ['concatenate_6[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 111)  444        ['concatenate_7[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 111)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 48)   5376        ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 48)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 12)   5196        ['activation_16[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 32, 32, 123)  0           ['concatenate_7[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 123)  492        ['concatenate_8[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 123)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 48)   5952        ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 48)  192         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_18[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 12)   5196        ['activation_18[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 135)  0           ['concatenate_8[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 135)  540        ['concatenate_9[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 32, 32, 135)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 48)   6528        ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 48)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 12)   5196        ['activation_20[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 32, 32, 147)  0           ['concatenate_9[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 32, 32, 147)  588        ['concatenate_10[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 32, 32, 147)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 48)   7104        ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 48)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 12)   5196        ['activation_22[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 32, 32, 159)  0           ['concatenate_10[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 159)  636        ['concatenate_11[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 32, 32, 159)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 48)   7680        ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 48)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_24[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 12)   5196        ['activation_24[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 32, 32, 171)  0           ['concatenate_11[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 171)  684        ['concatenate_12[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 32, 32, 171)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 48)   8256        ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 48)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 12)   5196        ['activation_26[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 32, 32, 183)  0           ['concatenate_12[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 183)  732        ['concatenate_13[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 32, 32, 183)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 48)   8832        ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 48)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 12)   5196        ['activation_28[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 32, 32, 195)  0           ['concatenate_13[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 195)  780        ['concatenate_14[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 32, 32, 195)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 48)   9408        ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 48)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 12)   5196        ['activation_30[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 32, 32, 207)  0           ['concatenate_14[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 207)  828        ['concatenate_15[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 32, 32, 207)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 48)   9984        ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 48)  192         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 12)   5196        ['activation_32[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 32, 32, 219)  0           ['concatenate_15[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 32, 32, 219)  876        ['concatenate_16[0][0]']
#  ormalization)
#
#  conv2d_33 (Conv2D)             (None, 32, 32, 108)  23760       ['batch_normalization_33[0][0]']
#
#  average_pooling2d (AveragePool  (None, 16, 16, 108)  0          ['conv2d_33[0][0]']
#  ing2D)
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 108)  432        ['average_pooling2d[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 16, 16, 108)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 48)   5232        ['activation_33[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 48)  192         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 12)   5196        ['activation_34[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 16, 16, 120)  0           ['average_pooling2d[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 120)  480        ['concatenate_17[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 16, 16, 120)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 48)   5808        ['activation_35[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 48)  192         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_37[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 12)   5196        ['activation_36[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 16, 16, 132)  0           ['concatenate_17[0][0]',
#                                                                   'conv2d_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 132)  528        ['concatenate_18[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 16, 16, 132)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 48)   6384        ['activation_37[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 16, 16, 48)  192         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 16, 16, 12)   5196        ['activation_38[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 16, 16, 144)  0           ['concatenate_18[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 16, 16, 144)  576        ['concatenate_19[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 16, 16, 144)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 16, 16, 48)   6960        ['activation_39[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 16, 16, 48)  192         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 12)   5196        ['activation_40[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 16, 16, 156)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 156)  624        ['concatenate_20[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 16, 16, 156)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 48)   7536        ['activation_41[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 48)  192         ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_43[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 12)   5196        ['activation_42[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 16, 16, 168)  0           ['concatenate_20[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 16, 16, 168)  672        ['concatenate_21[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 16, 16, 168)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 48)   8112        ['activation_43[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 16, 16, 48)  192         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 12)   5196        ['activation_44[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 16, 16, 180)  0           ['concatenate_21[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 16, 16, 180)  720        ['concatenate_22[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 16, 16, 180)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 48)   8688        ['activation_45[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 16, 16, 48)  192         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_47[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 12)   5196        ['activation_46[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 16, 16, 192)  0           ['concatenate_22[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 16, 16, 192)  768        ['concatenate_23[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 48)   9264        ['activation_47[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 16, 16, 48)  192         ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_49[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 16, 16, 12)   5196        ['activation_48[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 16, 16, 204)  0           ['concatenate_23[0][0]',
#                                                                   'conv2d_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 16, 16, 204)  816        ['concatenate_24[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 16, 16, 204)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 16, 16, 48)   9840        ['activation_49[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 16, 16, 48)  192         ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 16, 16, 12)   5196        ['activation_50[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 16, 16, 216)  0           ['concatenate_24[0][0]',
#                                                                   'conv2d_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 16, 16, 216)  864        ['concatenate_25[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 16, 16, 216)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 16, 16, 48)   10416       ['activation_51[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 16, 16, 48)  192         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_53[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 16, 16, 12)   5196        ['activation_52[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 16, 16, 228)  0           ['concatenate_25[0][0]',
#                                                                   'conv2d_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 16, 16, 228)  912        ['concatenate_26[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 16, 16, 228)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 16, 16, 48)   10992       ['activation_53[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 16, 16, 48)  192         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 16, 16, 48)   0           ['batch_normalization_55[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 16, 16, 12)   5196        ['activation_54[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 16, 16, 240)  0           ['concatenate_26[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 16, 16, 240)  960        ['concatenate_27[0][0]']
#  ormalization)
# ...
#
#  activation_79 (Activation)     (None, 8, 8, 234)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 8, 8, 48)     11280       ['activation_79[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 8, 8, 48)    192         ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 8, 8, 48)     0           ['batch_normalization_82[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 8, 8, 12)     5196        ['activation_80[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 8, 8, 246)    0           ['concatenate_39[0][0]',
#                                                                   'conv2d_82[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 8, 8, 246)   984         ['concatenate_40[0][0]']
#  ormalization)
#
#  activation_81 (Activation)     (None, 8, 8, 246)    0           ['batch_normalization_83[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 8, 8, 48)     11856       ['activation_81[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 8, 8, 48)    192         ['conv2d_83[0][0]']
#  ormalization)
#
#  activation_82 (Activation)     (None, 8, 8, 48)     0           ['batch_normalization_84[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 8, 8, 12)     5196        ['activation_82[0][0]']
#
#  concatenate_41 (Concatenate)   (None, 8, 8, 258)    0           ['concatenate_40[0][0]',
#                                                                   'conv2d_84[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 258)   1032        ['concatenate_41[0][0]']
#  ormalization)
#
#  activation_83 (Activation)     (None, 8, 8, 258)    0           ['batch_normalization_85[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 48)     12432       ['activation_83[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 48)    192         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_84 (Activation)     (None, 8, 8, 48)     0           ['batch_normalization_86[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 8, 8, 12)     5196        ['activation_84[0][0]']
#
#  concatenate_42 (Concatenate)   (None, 8, 8, 270)    0           ['concatenate_41[0][0]',
#                                                                   'conv2d_86[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 270)   1080        ['concatenate_42[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 270)    0           ['batch_normalization_87[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 48)     13008       ['activation_85[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 48)    192         ['conv2d_87[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 8, 8, 48)     0           ['batch_normalization_88[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 12)     5196        ['activation_86[0][0]']
#
#  concatenate_43 (Concatenate)   (None, 8, 8, 282)    0           ['concatenate_42[0][0]',
#                                                                   'conv2d_88[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 282)   1128        ['concatenate_43[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 282)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 48)     13584       ['activation_87[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 48)    192         ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_88 (Activation)     (None, 8, 8, 48)     0           ['batch_normalization_90[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 12)     5196        ['activation_88[0][0]']
#
#  concatenate_44 (Concatenate)   (None, 8, 8, 294)    0           ['concatenate_43[0][0]',
#                                                                   'conv2d_90[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 294)   1176        ['concatenate_44[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 294)    0           ['batch_normalization_91[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 48)     14160       ['activation_89[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 48)    192         ['conv2d_91[0][0]']
#  ormalization)
#
#  activation_90 (Activation)     (None, 8, 8, 48)     0           ['batch_normalization_92[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 12)     5196        ['activation_90[0][0]']
#
#  concatenate_45 (Concatenate)   (None, 8, 8, 306)    0           ['concatenate_44[0][0]',
#                                                                   'conv2d_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 306)   1224        ['concatenate_45[0][0]']
#  ormalization)
#
#  activation_91 (Activation)     (None, 8, 8, 306)    0           ['batch_normalization_93[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 48)     14736       ['activation_91[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 8, 8, 48)    192         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_92 (Activation)     (None, 8, 8, 48)     0           ['batch_normalization_94[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 8, 8, 12)     5196        ['activation_92[0][0]']
#
#  concatenate_46 (Concatenate)   (None, 8, 8, 318)    0           ['concatenate_45[0][0]',
#                                                                   'conv2d_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 8, 8, 318)   1272        ['concatenate_46[0][0]']
#  ormalization)
#
#  activation_93 (Activation)     (None, 8, 8, 318)    0           ['batch_normalization_95[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 8, 8, 48)     15312       ['activation_93[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 8, 8, 48)    192         ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_94 (Activation)     (None, 8, 8, 48)     0           ['batch_normalization_96[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 8, 8, 12)     5196        ['activation_94[0][0]']
#
#  concatenate_47 (Concatenate)   (None, 8, 8, 330)    0           ['concatenate_46[0][0]',
#                                                                   'conv2d_96[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 8, 8, 330)   1320        ['concatenate_47[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (None, 8, 8, 330)    0           ['batch_normalization_97[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 8, 8, 48)     15888       ['activation_95[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 8, 8, 48)    192         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_96 (Activation)     (None, 8, 8, 48)     0           ['batch_normalization_98[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 8, 8, 12)     5196        ['activation_96[0][0]']
#
#  concatenate_48 (Concatenate)   (None, 8, 8, 342)    0           ['concatenate_47[0][0]',
#                                                                   'conv2d_98[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 1, 1, 342)   0           ['concatenate_48[0][0]']
#  oling2D)
#
#  flatten (Flatten)              (None, 342)          0           ['average_pooling2d_2[0][0]']
#
#  dense (Dense)                  (None, 10)           3430        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 797,788
# Trainable params: 774,376
# Non-trainable params: 23,412
# __________________________________________________________________________________________________

# %% [markdown]
# prepare model model saving directory

# %%
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_densenet_model.{epoch:02d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %% [markdown]
# prepare callbacks for model saving and for learning rate reducer

# %%
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

# %%
lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

# %%
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %% [markdown]
# run training, with or without data augmentation

# %%
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # preprocessing  and realtime data augmentation
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (deg 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally
        height_shift_range=0.1,  # randomly shift images vertically
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images

    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied)
    datagen.fit(x_train)
    steps_per_epoch = math.ceil(len(x_train) / batch_size)
    # fit the model on the batches generated by datagen.flow().
    model.fit(x=datagen.flow(x_train, y_train, batch_size=batch_size),
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),
              steps_per_epoch=steps_per_epoch,
              callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Learning rate:  0.001
# Epoch 1/200
# 2022-11-13 20:38:10.748679: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:2693, in Operation.get_attr(self, name)
#    2692 with c_api_util.tf_buffer() as buf:
# -> 2693   pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2694   data = pywrap_tf_session.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'model/conv2d_29/BiasAdd/ReadVariableOp/resource' has no attr named '_class'.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [21], line 29
#      27 steps_per_epoch = math.ceil(len(x_train) / batch_size)
#      28 # fit the model on the batches generated by datagen.flow().
# ---> 29 model.fit(x=datagen.flow(x_train, y_train, batch_size=batch_size),
#      30           verbose=1,
#      31           epochs=epochs,
#      32           validation_data=(x_test, y_test),
#      33           steps_per_epoch=steps_per_epoch,
#      34           callbacks=callbacks)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:980, in Function._call(self, *args, **kwds)
#     976     pass  # Fall through to cond-based initialization.
#     977   else:
#     978     # Lifting succeeded, so variables are initialized and we can run the
#     979     # stateless function.
# --> 980     return self._stateless_fn(*args, **kwds)
#     981 else:
#     982   _, _, filtered_flat_args = (
#     983       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     984           *args, **kwds))
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2495, in Function.__call__(self, *args, **kwargs)
#    2492 """Calls a graph function specialized to the inputs."""
#    2493 with self._lock:
#    2494   (graph_function,
# -> 2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2760, in Function._maybe_define_function(self, args, kwargs)
#    2758   # Only get placeholders for arguments, not captures
#    2759   args, kwargs = placeholder_dict["args"]
# -> 2760 graph_function = self._create_graph_function(args, kwargs)
#    2762 graph_capture_container = graph_function.graph._capture_func_lib  # pylint: disable=protected-access
#    2763 # Maintain the list of all captures
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2670, in Function._create_graph_function(self, args, kwargs)
#    2665 missing_arg_names = [
#    2666     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2667 ]
#    2668 arg_names = base_arg_names + missing_arg_names
#    2669 graph_function = ConcreteFunction(
# -> 2670     func_graph_module.func_graph_from_py_func(
#    2671         self._name,
#    2672         self._python_function,
#    2673         args,
#    2674         kwargs,
#    2675         self.input_signature,
#    2676         autograph=self._autograph,
#    2677         autograph_options=self._autograph_options,
#    2678         arg_names=arg_names,
#    2679         capture_by_value=self._capture_by_value),
#    2680     self._function_attributes,
#    2681     spec=self.function_spec,
#    2682     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2683     # scope. This is not the default behavior since it gets used in some
#    2684     # places (like Keras) where the FuncGraph lives longer than the
#    2685     # ConcreteFunction.
#    2686     shared_func_graph=False)
#    2687 return graph_function
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1247, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1244 else:
#    1245   _, original_func = tf_decorator.unwrap(python_func)
# -> 1247 func_outputs = python_func(*func_args, **func_kwargs)
#    1249 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1250 # TensorArrays and `None`s.
#    1251 func_outputs = nest.map_structure(
#    1252     convert, func_outputs, expand_composites=True)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:677, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     673 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     674   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     675   # the function a weak reference to itself to avoid a reference cycle.
#     676   with OptionalXlaContext(compile_with_xla):
# --> 677     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678   return out
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1222, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1220 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1221 try:
# -> 1222   return autograph.converted_call(
#    1223       original_func,
#    1224       args,
#    1225       kwargs,
#    1226       options=autograph.ConversionOptions(
#    1227           recursive=True,
#    1228           optional_features=autograph_options,
#    1229           user_requested=True,
#    1230       ))
#    1231 except Exception as e:  # pylint:disable=broad-except
#    1232   if hasattr(e, "ag_error_metadata"):
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File /var/folders/54/swp46mk10nqbw3sppywrcz0m0000gn/T/__autograph_generated_filevgfejc80.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/keras/engine/training.py:1146, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1142     run_step = tf.function(
#    1143         run_step, jit_compile=True, reduce_retracing=True
#    1144     )
#    1145 data = next(iterator)
# -> 1146 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1147 outputs = reduce_per_replica(
#    1148     outputs, self.distribute_strategy, reduction="first"
#    1149 )
#    1150 return outputs
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:1315, in StrategyBase.run(***failed resolving arguments***)
#    1310 with self.scope():
#    1311   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1312   # applied when the caller is also in Eager mode.
#    1313   fn = autograph.tf_convert(
#    1314       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1315   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:2891, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2889   kwargs = {}
#    2890 with self._container_strategy().scope():
# -> 2891   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:3692, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3690 def _call_for_each_replica(self, fn, args, kwargs):
#    3691   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3692     return fn(*args, **kwargs)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/keras/engine/training.py:1135, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1134 def run_step(data):
# -> 1135     outputs = model.train_step(data)
#    1136     # Ensure counter is updated only if `train_step` succeeds.
#    1137     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/keras/engine/training.py:997, in Model.train_step(self, data)
#     995 self._validate_target_and_loss(y, loss)
#     996 # Run backwards pass.
# --> 997 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     998 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/optimizer_v2.py:579, in OptimizerV2.minimize(self, loss, var_list, grad_loss, name, tape)
#     546 """Minimize `loss` by updating `var_list`.
#     547
#     548 This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     574
#     575 """
#     576 grads_and_vars = self._compute_gradients(
#     577     loss, var_list=var_list, grad_loss=grad_loss, tape=tape
#     578 )
# --> 579 return self.apply_gradients(grads_and_vars, name=name)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/optimizer_v2.py:738, in OptimizerV2.apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     735     grads_and_vars = self._aggregate_gradients(grads_and_vars)
#     736 grads_and_vars = self._transform_gradients(grads_and_vars)
# --> 738 return tf.__internal__.distribute.interim.maybe_merge_call(
#     739     functools.partial(
#     740         self._distributed_apply, apply_state=apply_state
#     741     ),
#     742     strategy,
#     743     grads_and_vars,
#     744     name=name,
#     745 )
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/distribute/merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribution_strategy_context.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/optimizer_v2.py:797, in OptimizerV2._distributed_apply(self, distribution, grads_and_vars, apply_state, name)
#     791 with distribution.extended.colocate_vars_with(var):
#     792     with name_scope_only_in_function_or_graph(
#     793         "update"
#     794         if eagerly_outside_functions
#     795         else "update_" + var.op.name
#     796     ):
# --> 797         update_op = distribution.extended.update(
#     798             var,
#     799             apply_grad_to_update_var,
#     800             args=(grad,),
#     801             group=False,
#     802         )
#     803         if tf.distribute.in_cross_replica_context():
#     804             # In cross-replica context, extended.update returns
#     805             # a list of update ops from all replicas
#     806             # (group=False).
#     807             update_ops.extend(update_op)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:2635, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    2633     return self._update(var, fn, args, kwargs, group)
#    2634 else:
# -> 2635   return self._replica_ctx_update(
#    2636       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:2514, in StrategyExtendedV2._replica_ctx_update(self, var, fn, args, kwargs, group)
#    2511 def merge_fn(_, *merged_args, **merged_kwargs):
#    2512   return self.update(var, fn, merged_args, merged_kwargs, group=group)
# -> 2514 return replica_context.merge_call(merge_fn, args=args, kwargs=kwargs)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:3106, in ReplicaContextBase.merge_call(self, merge_fn, args, kwargs)
#    3102   kwargs = {}
#    3104 merge_fn = autograph.tf_convert(
#    3105     merge_fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 3106 return self._merge_call(merge_fn, args, kwargs)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:3113, in ReplicaContextBase._merge_call(self, merge_fn, args, kwargs)
#    3110 _push_per_thread_mode(  # thread-local, so not needed with multiple threads
#    3111     distribution_strategy_context._CrossReplicaThreadMode(self._strategy))  # pylint: disable=protected-access
#    3112 try:
# -> 3113   return merge_fn(self._strategy, *args, **kwargs)
#    3114 finally:
#    3115   _pop_per_thread_mode()
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:2512, in StrategyExtendedV2._replica_ctx_update.<locals>.merge_fn(_, *merged_args, **merged_kwargs)
#    2511 def merge_fn(_, *merged_args, **merged_kwargs):
# -> 2512   return self.update(var, fn, merged_args, merged_kwargs, group=group)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:2633, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    2630   fn = autograph.tf_convert(
#    2631       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2632   with self._container_strategy().scope():
# -> 2633     return self._update(var, fn, args, kwargs, group)
#    2634 else:
#    2635   return self._replica_ctx_update(
#    2636       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:3706, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    3703 def _update(self, var, fn, args, kwargs, group):
#    3704   # The implementations of _update() and _update_non_slot() are identical
#    3705   # except _update() passes `var` as the first argument to `fn()`.
# -> 3706   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:3712, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    3708 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    3709   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    3710   # once that value is used for something.
#    3711   with UpdateContext(colocate_with):
# -> 3712     result = fn(*args, **kwargs)
#    3713     if should_group:
#    3714       return result
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/optimizer_v2.py:776, in OptimizerV2._distributed_apply.<locals>.apply_grad_to_update_var(var, grad)
#     774 if "apply_state" in self._dense_apply_args:
#     775     apply_kwargs["apply_state"] = apply_state
# --> 776 update_op = self._resource_apply_dense(grad, var, **apply_kwargs)
#     777 if var.constraint is not None:
#     778     with tf.control_dependencies([update_op]):
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/rmsprop.py:227, in RMSprop._resource_apply_dense(self, grad, var, apply_state)
#     223 else:
#     224     rms_t = coefficients["rho"] * rms + coefficients[
#     225         "one_minus_rho"
#     226     ] * tf.square(grad)
# --> 227     rms_t = tf.compat.v1.assign(
#     228         rms, rms_t, use_locking=self._use_locking
#     229     )
#     230     denom_t = rms_t
#     231     if self.centered:
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/ops/state_ops.py:355, in assign(ref, value, validate_shape, use_locking, name)
#     351 if ref.dtype._is_ref_dtype:
#     352   return gen_state_ops.assign(
#     353       ref, value, use_locking=use_locking, name=name,
#     354       validate_shape=validate_shape)
# --> 355 return ref.assign(value, name=name)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:941, in BaseResourceVariable.assign(self, value, use_locking, name, read_value)
#     939   validate_shape = self._validate_shape and self._shape.is_fully_defined()
#     940   kwargs["validate_shape"] = validate_shape
# --> 941 assign_op = gen_resource_variable_ops.assign_variable_op(
#     942     self.handle, value_tensor, name=name, **kwargs)
#     943 if read_value:
#     944   return self._lazy_read(assign_op)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py:159, in assign_variable_op(resource, value, validate_shape, name)
#     157   validate_shape = False
#     158 validate_shape = _execute.make_bool(validate_shape, "validate_shape")
# --> 159 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     160       "AssignVariableOp", resource=resource, value=value,
#     161                           validate_shape=validate_shape, name=name)
#     162 return _op
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/framework/op_def_library.py:797, in _apply_op_helper(op_type_name, name, **keywords)
#     792 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     793                         if arg.is_ref]
#     794 with _MaybeColocateWith(must_colocate_inputs):
#     795   # Add Op to graph
#     796   # pylint: disable=protected-access
# --> 797   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     798                              name=scope, input_types=input_types,
#     799                              attrs=attr_protos, op_def=op_def)
#     801 # `outputs` is returned as a separate return value so that the output
#     802 # tensors can the `op` per se can be decoupled so that the
#     803 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     804 # for more details.
#     805 outputs = op.outputs
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:735, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     733   inp = self.capture(inp)
#     734   captured_inputs.append(inp)
# --> 735 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     736     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     737     compute_device)
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:3809, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3799 with self._mutation_lock():
#    3800   ret = Operation(
#    3801       node_def,
#    3802       self,
#    (...)
#    3807       original_op=self._default_original_op,
#    3808       op_def=op_def)
# -> 3809   self._create_op_helper(ret, compute_device=compute_device)
#    3810 return ret
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:3898, in Graph._create_op_helper(self, op, compute_device)
#    3896 for colocation_op in self._colocation_stack.peek_objs():
#    3897   try:
# -> 3898     all_colocation_groups.extend(colocation_op.colocation_groups())
#    3899   except AttributeError:
#    3900     pass
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:2211, in Operation.colocation_groups(self)
#    2209 default_colocation_group = [compat.as_bytes("loc:@%s" % self.name)]
#    2210 try:
# -> 2211   class_attr = self.get_attr("_class")
#    2212 except ValueError:
#    2213   # This op has no explicit colocation group, so it is itself its
#    2214   # own root of a colocation group.
#    2215   return default_colocation_group
#
# File ~/miniconda/envs/tf/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:2693, in Operation.get_attr(self, name)
#    2691 try:
#    2692   with c_api_util.tf_buffer() as buf:
# -> 2693     pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2694     data = pywrap_tf_session.TF_GetBuffer(buf)
#    2695 except errors.InvalidArgumentError as e:
#    2696   # Convert to ValueError for backwards compatibility.
#
# KeyboardInterrupt:

# %%
    # fit the model on the batches generated by datagen.flow()
    #model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
    ##                    steps_per_epoch=x_train.shape[0] // batch_size,
    #                    validation_data=(x_test, y_test),
    #                    epochs=epochs, verbose=1,
    #                    callbacks=callbacks)

# %% [markdown]
# score trained model

# %%
scores = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
